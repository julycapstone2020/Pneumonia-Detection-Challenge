# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !ls -la "/content/gdrive/My Drive/darknet"
# !ln -s /content/gdrive/My\ Drive/ /mydrive

#! ls -lt "/content/gdrive/My Drive/darknet/cuDNN"
#! mv "/content/gdrive/My Drive/darknet/cuDNN/cudnn-10.0-linux-x64-v7.5.0.56 (1).tgz" "/content/gdrive/My Drive/darknet/cuDNN/cudnn-10.0-linux-x64-v7.5.0.56.tgz"
#! ls -lt "/content/gdrive/My Drive/darknet/cuDNN"
# Out:
# total 31
# drwx------ 2 root root 4096 Jul 28 13:28 backup
# drwx------ 2 root root 4096 Jul 29 08:13 bin
# drwx------ 2 root root 4096 Jul 29 08:13 cfg
# drwx------ 2 root root 4096 Jul 28 13:29 check
# drwx------ 2 root root 4096 Jul 28 12:07 cuDNN
# drwx------ 2 root root 4096 Jul 28 12:09 img
# -rw------- 1 root root  220 Jul 29 08:17 obj.data
# -rw------- 1 root root    9 Jul 29 08:17 obj.names
# -rw------- 1 root root    0 Jul 29 08:18 test.txt
# -rw------- 1 root root 1223 Jul 29 08:18 train.txt
# drwx------ 2 root root 4096 Jul 28 13:29 weights

# %%
% cd /content
# !pwd
# !mkdir darknet darknet/backup darknet/bin darknet/cfg darknet/cuDNN darknet/img darknet/weights
# !ls /content/darknet
# Out:
# /content
# /content
# mkdir: cannot create directory ‘darknet’: File exists
# mkdir: cannot create directory ‘darknet/backup’: File exists
# mkdir: cannot create directory ‘darknet/bin’: File exists
# mkdir: cannot create directory ‘darknet/cfg’: File exists
# mkdir: cannot create directory ‘darknet/cuDNN’: File exists
# mkdir: cannot create directory ‘darknet/img’: File exists
# mkdir: cannot create directory ‘darknet/weights’: File exists
# backup	bin  cfg  cuDNN  img  weights

# %%
! ls -lt /mydrive/darknet/cuDNN/
# %cp /mydrive/darknet/cuDNN/cudnn-10.0-linux-x64-v7.5.0.56.tgz /content/darknet/cuDNN/
# Out:
# total 422668
# -rw------- 1 root root 432811879 Jul 28 07:19 cudnn-10.0-linux-x64-v7.5.0.56.tgz

# %%
# !ls -lt "/content/darknet/cuDNN"
! ls -lt  /mydrive/darknet/weights
! ls -lt  /mydrive/darknet/cfg
# Out:
# total 422668
# -rw------- 1 root root 432811879 Jul 29 09:06 cudnn-10.0-linux-x64-v7.5.0.56.tgz
# total 166054
# -rw------- 1 root root 170038676 Jul 29 08:10 yolov4.conv.137
# total 14
# -rw------- 1 root root 13404 Jul 29 08:10 yolov4-custom.cfg

# %%
# %cp /mydrive/darknet/cfg/yolov4-custom.cfg /content/darknet/cfg/
# %cp /mydrive/darknet/cfg/yolov3.cfg /content/darknet/cfg/
# %cp /mydrive/darknet/weights/darknet53.conv.74 /content/darknet/weights/
# %cp /mydrive/darknet/img/* /content/darknet/img/
# %cp /mydrive/darknet/weights/yolov4.conv.137 /content/darknet/weights/
# %cp /mydrive/darknet/obj.data /content/darknet
# %cp /mydrive/darknet/obj.names /content/darknet
# %cp /mydrive/darknet/test.txt /content/darknet
# %cp /mydrive/darknet/train.txt /content/darknet
! ls -lR /content/darknet
# Out:
# /content/darknet:
# total 36
# drwxr-xr-x 2 root root 4096 Jul 29 08:54 backup
# drwxr-xr-x 2 root root 4096 Jul 29 08:54 bin
# drwxr-xr-x 2 root root 4096 Jul 29 09:10 cfg
# drwxr-xr-x 2 root root 4096 Jul 29 08:57 cuDNN
# drwxr-xr-x 2 root root 4096 Jul 29 09:09 img
# -rw------- 1 root root  220 Jul 29 09:10 obj.data
# -rw------- 1 root root    9 Jul 29 09:10 obj.names
# -rw------- 1 root root    0 Jul 29 09:10 test.txt
# -rw------- 1 root root 1223 Jul 29 09:10 train.txt
# drwxr-xr-x 2 root root 4096 Jul 29 09:10 weights
#
# /content/darknet/backup:
# total 0
#
# /content/darknet/bin:
# total 0
#
# /content/darknet/cfg:
# total 16
# -rw------- 1 root root 13404 Jul 29 09:10 yolov4-custom.cfg
#
# /content/darknet/cuDNN:
# total 422668
# -rw------- 1 root root 432811879 Jul 29 09:06 cudnn-10.0-linux-x64-v7.5.0.56.tgz
#
# /content/darknet/img:
# total 1128
# -rw------- 1 root root 43685 Jul 29 09:10 000000.jpg
# -rw------- 1 root root     0 Jul 29 09:10 000000.txt
# ...

# %%
# !sudo apt-get install tree
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 40.7 kB of archives.
# After this operation, 105 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tree amd64 1.7.0-5 [40.7 kB]
# Fetched 40.7 kB in 0s (1,152 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %%
# !tree /content/gdrive/My\ Drive/darknet/
# Out:
# /content/gdrive/My Drive/darknet/
# ├── backup
# ├── bin
# ├── cfg
# │   └── yolov4-custom.cfg
# ├── check
# ├── cuDNN
# │   └── cudnn-10.0-linux-x64-v7.5.0.56.tgz
# ├── img
# │   ├── 000000.jpg
# │   ├── 000000.txt
# │   ├── 000001.jpg
# │   ├── 000001.txt
# │   ├── 000002.jpg
# │   ├── 000002.txt
# │   ├── 000003.jpg
# │   ├── 000003.txt
# │   ├── 000004.jpg
# │   ├── 000004.txt
# │   ├── 000005.jpg
# │   ├── 000005.txt
# │   ├── 000006.jpg
# │   ├── 000006.txt
# │   ├── 000007.jpg
# │   ├── 000007.txt
# │   ├── 000008.jpg
# │   ├── 000008.txt
# │   ├── 000009.jpg
# │   ├── 000009.txt
# │   ├── 000010.jpg
# │   ├── 000010.txt
# │   ├── 000011.jpg
# │   ├── 000011.txt
# │   ├── 000012.jpg
# │   ├── 000012.txt
# │   ├── 000013.jpg
# │   ├── 000013.txt
# │   ├── 000014.jpg
# │   ├── 000014.txt
# │   ├── 000015.jpg
# │   ├── 000015.txt
# │   ├── 000016.jpg
# │   ├── 000016.txt
# │   ├── 000017.jpg
# │   ├── 000017.txt
# │   ├── 000018.jpg
# │   ├── 000018.txt
# │   ├── 000019.jpg
# ...

# %%
! uname -r
# Out:
# 4.19.104+

# %%
 ! cat /proc/version
# Out:
# Linux version 4.19.104+ (chrome-bot@chromeos-ci-legacy-us-central1-b-x32-96-hq3l) (Chromium OS 9.0_pre361749_p20190714-r4 clang version 9.0.0 (/var/cache/chromeos-cache/distfiles/host/egit-src/llvm-project c11de5eada2decd0a495ea02676b6f4838cd54fb) (based on LLVM 9.0.0svn)) #1 SMP Wed Feb 19 05:26:34 PST 2020

# %%
! cat /etc/os-release
# Out:
# NAME="Ubuntu"
# VERSION="18.04.3 LTS (Bionic Beaver)"
# ID=ubuntu
# ID_LIKE=debian
# PRETTY_NAME="Ubuntu 18.04.3 LTS"
# VERSION_ID="18.04"
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# VERSION_CODENAME=bionic
# UBUNTU_CODENAME=bionic

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
# !tar -xzvf /content/darknet/cuDNN/cudnn-10.0-linux-x64-v7.5.0.56.tgz -C /usr/local/
# Out:
# cuda/include/cudnn.h
# cuda/NVIDIA_SLA_cuDNN_Support.txt
# cuda/lib64/libcudnn.so
# cuda/lib64/libcudnn.so.7
# cuda/lib64/libcudnn.so.7.5.0
# cuda/lib64/libcudnn_static.a

# %%
# !chmod a+r /usr/local/cuda/include/cudnn.h

# %%
# !cat /usr/local/cuda/include/cudnn.h | grep CUDNN_MAJOR -A 2
# Out:
# #define CUDNN_MAJOR 7
# #define CUDNN_MINOR 5
# #define CUDNN_PATCHLEVEL 0
# --
# #define CUDNN_VERSION (CUDNN_MAJOR * 1000 + CUDNN_MINOR * 100 + CUDNN_PATCHLEVEL)
#
# #include "driver_types.h"

# %%
! pwd
! ls -lt
# Out:
# /content
# total 12
# drwxr-xr-x 8 root root 4096 Jul 29 09:06 darknet
# drwx------ 4 root root 4096 Jul 29 08:54 gdrive
# drwxr-xr-x 1 root root 4096 Jul 10 16:29 sample_data

# %%
# Out:
# /content/darknet

# %%
##  Cloning and compiling Darkent. ONLY NEEDS TO BE RUN ON THE FIRST EXECUTION!!
% cd /content/darknet/
# !git clone https://github.com/kriyeng/darknet/
% cd darknet/
# Out:
# /content/darknet
# fatal: destination path 'darknet' already exists and is not an empty directory.
# /content/darknet/darknet

# %%
# !ls
# Out:
# 3rdparty      CMakeLists.txt	      image_yolov3.sh	     scripts
# appveyor.yml  CMakeSettings.json      include		     src
# build	      DarknetConfig.cmake.in  json_mjpeg_streams.sh  video_v2.sh
# build.ps1     darknet.py	      LICENSE		     video_yolov3.sh
# build.sh      darknet_video.py	      Makefile
# cfg	      data		      net_cam_v3.sh
# cmake	      image_yolov2.sh	      README.md

# %%
#Compile Darknet
# !make
# Out:
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -c ./src/image_opencv.cpp -o obj/image_opencv.o
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:228:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# gcc -Iinclude/ -I3rdparty/stb/include -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘convolution_2d’:
# ./src/gemm.c:2016:15: warning: unused variable ‘out_w’ [-Wunused-variable]
# ...

# %%
! pwd
# Out:
# /content/darknet/darknet

# %%
! ls -lt
# Out:
# total 952
# -rwxr-xr-x 1 root root 763000 Jul 29 09:15 darknet
# drwxr-xr-x 2 root root   4096 Jul 29 09:15 obj
# drwxr-xr-x 2 root root   4096 Jul 29 09:15 results
# drwxr-xr-x 2 root root   4096 Jul 29 09:15 backup
# drwxr-xr-x 2 root root   4096 Jul 29 09:14 src
# -rwxr-xr-x 1 root root    108 Jul 29 09:14 video_v2.sh
# -rwxr-xr-x 1 root root    108 Jul 29 09:14 video_yolov3.sh
# drwxr-xr-x 4 root root   4096 Jul 29 09:14 scripts
# -rwxr-xr-x 1 root root    345 Jul 29 09:14 json_mjpeg_streams.sh
# -rwxr-xr-x 1 root root    159 Jul 29 09:14 net_cam_v3.sh
# drwxr-xr-x 3 root root   4096 Jul 29 09:14 data
# -rwxr-xr-x 1 root root    108 Jul 29 09:14 image_yolov2.sh
# -rwxr-xr-x 1 root root    110 Jul 29 09:14 image_yolov3.sh
# drwxr-xr-x 2 root root   4096 Jul 29 09:14 include
# drwxr-xr-x 3 root root   4096 Jul 29 09:14 cfg
# drwxr-xr-x 3 root root   4096 Jul 29 09:14 cmake
# -rw-r--r-- 1 root root  16255 Jul 29 09:14 darknet.py
# ...

# %%
! pwd
#Copies the Darknet compiled version to Google drive
# !cp ./darknet /content/gdrive/My\ Drive/darknet/bin/
! ls -lt /content/gdrive/My\ Drive/darknet/bin/
! date
# Out:
# /content/darknet/darknet
# total 746
# -rw------- 1 root root 763000 Jul 29 09:17 darknet
# Wed Jul 29 09:17:43 UTC 2020

# %%
#! ls -Rlt /content/gdrive/My\ Drive/darknet/bin/darknet

# %%
! ls -lt darknet
# !chmod +x ./darknet
! ls -lt darknet
# Out:
# -rwxr-xr-x 1 root root 763000 Jul 29 09:15 darknet
# -rwxr-xr-x 1 root root 763000 Jul 29 09:15 darknet

# %%
#download files
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  #plt.rcParams['figure.figsize'] = [10, 5]
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()
  
  
def upload():
  from google.colab import files
  uploaded = files.upload() 
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)
def download(path):
  from google.colab import files
  files.download(path)

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2020-07-29 09:20:37--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M   222KB/s    in 24m 40s
#
# 2020-07-29 09:45:19 (164 KB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
## GPUs on this VM
% cd /proc/driver/nvidia/gpus
# !pwd
! ls
# Out:
# /proc/driver/nvidia/gpus
# /proc/driver/nvidia/gpus
# 0000:00:04.0

# %%
## copy your custom images to darknet/data
% cd /content/darknet/darknet
! ls
! ls data
# !ls /mydrive/darknet/img/*.JPG
% cp /mydrive/darknet/img/*.JPG data/
! ls data/
! mkdir log
# Out:
# /content/darknet/darknet
# 3rdparty      CMakeLists.txt	      image_yolov3.sh	     README.md
# appveyor.yml  CMakeSettings.json      include		     results
# backup	      darknet		      json_mjpeg_streams.sh  scripts
# build	      DarknetConfig.cmake.in  LICENSE		     src
# build.ps1     darknet.py	      Makefile		     video_v2.sh
# build.sh      darknet_video.py	      net_cam_v3.sh	     video_yolov3.sh
# cfg	      data		      obj		     yolov3.weights
# cmake	      image_yolov2.sh	      predictions.jpg
# 9k.tree     eagle.jpg	 imagenet.labels.list	   openimages.names  two.JPG
# coco9k.map  giraffe.jpg  imagenet.shortnames.list  person.jpg	     voc.names
# coco.names  goal.txt	 labels			   scream.jpg
# dog.jpg     horses.jpg	 one.JPG		   three.JPG
# /mydrive/darknet/img/one.JPG	/mydrive/darknet/img/two.JPG
# /mydrive/darknet/img/three.JPG
# 9k.tree     eagle.jpg	 imagenet.labels.list	   openimages.names  two.JPG
# ...

# %%
# Not necessary cell
# Execute darknet using YOLOv3 model with pre-trained weights to detect objects on 'person.jpg'
# !./darknet detect cfg/yolov3.cfg yolov3.weights data/three.JPG -dont-show

# Show the result using the helper imgShow()
imShow('predictions.jpg')
# Out:
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32 0.299 BF
#    1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64 1.595 BF
#    2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32 0.177 BF
#    3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128 1.595 BF
#    6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#    7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#   10 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
#   12 conv    256  3 x 3 / 2   104 x 104 x 128   ->    52 x  52 x 256 1.595 BF
# ...

# %%
# !./darknet detect cfg/yolov3.cfg yolov3.weights data/one.JPG -dont-show

# Show the result using the helper imgShow()
imShow('predictions.jpg')
# Out:
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32 0.299 BF
#    1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64 1.595 BF
#    2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32 0.177 BF
#    3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128 1.595 BF
#    6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#    7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#   10 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
#   12 conv    256  3 x 3 / 2   104 x 104 x 128   ->    52 x  52 x 256 1.595 BF
# ...

# %%
# !./darknet detect cfg/yolov3.cfg yolov3.weights data/two.JPG -dont-show

# Show the result using the helper imgShow()
imShow('predictions.jpg')
# Out:
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32 0.299 BF
#    1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64 1.595 BF
#    2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32 0.177 BF
#    3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128 1.595 BF
#    6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#    7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#   10 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
#   12 conv    256  3 x 3 / 2   104 x 104 x 128   ->    52 x  52 x 256 1.595 BF
# ...

# %%
##Lets train pneumonia images with yolo3 custom waits \
##(https://github.com/AlexeyAB/darknet#how-to-train-to-detect-your-custom-objects) 
! ls -lt /content/darknet/weights/
! ls -lt /content/darknet/cfg/
! ls -lt /content/darknet/obj.data
! cd /content/darknet/darknet/
! pwd
! ls -lt darknet
# Out:
# total 166060
# -rw------- 1 root root 170038676 Jul 29 09:10 yolov4.conv.137
# total 16
# -rw------- 1 root root 13404 Jul 29 09:10 yolov4-custom.cfg
# /content/darknet/darknet
# -rwxr-xr-x 1 root root 763000 Jul 29 09:15 darknet

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Out:
# --2020-07-29 10:03:57--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 18.214.118.253, 54.88.63.64, 34.227.164.168, ...
# Connecting to bin.equinox.io (bin.equinox.io)|18.214.118.253|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13773305 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.13M  11.8MB/s    in 1.1s
#
# 2020-07-29 10:03:59 (11.8 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13773305/13773305]

# %%
# !unzip ngrok-stable-linux-amd64.zip
get_ipython().system_raw('./ngrok http 8090 &')
# !curl -s http://localhost:4040/api/tunnels | python3 -c \
 "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# Archive:  ngrok-stable-linux-amd64.zip
# replace ngrok? [y]es, [n]o, [A]ll, [N]one, [r]ename:
# error:  invalid response [{ENTER}]
# replace ngrok? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# https://0b9aa55ffdac.ngrok.io

# %%
#! cp /mydrive/darknet/obj.data /content/darknet/

! ls -lt /content/darknet/weights/darknet53.conv.74
# Out:
# -rw------- 1 root root 162482580 Jul 29 12:11 /content/darknet/weights/darknet53.conv.74

# %%
! date ##@5:50pm IST

# !./darknet detector train "/content/darknet/obj.data" "/content/darknet/cfg/yolov3.cfg" \
"/content/darknet/weights/darknet53.conv.74" -dont_show -map

#! ./darknet detector train "/content/darknet/obj.data" "/content/darknet/yolov4-custom.cfg" \
 # "/content/darknet/weights/yolov4.conv.137" -dont_show -mjpeg_port 8090 -mjp -map \
 # backup/yolo_28jul.weights >> log/yolo_28jul.log

! date
# Out:
# Wed Jul 29 12:27:14 UTC 2020
#  Prepare additional network for mAP calculation...
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32 0.299 BF
#    1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64 1.595 BF
#    2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32 0.177 BF
#    3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128 1.595 BF
#    6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#    7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#   10 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
# ...

# %%
 ! ls -lt log/yolo_28jul.log
# Out:
# -rw-r--r-- 1 root root 0 Jul 29 10:00 log/yolo_28jul.log

# %%
! pwd
! ls
# Out:
# /content/darknet/darknet
# 3rdparty      CMakeLists.txt	      include		     results
# appveyor.yml  CMakeSettings.json      json_mjpeg_streams.sh  scripts
# backup	      darknet		      LICENSE		     src
# bad.list      DarknetConfig.cmake.in  Makefile		     train.txt
# build	      darknet.py	      net_cam_v3.sh	     video_v2.sh
# build.ps1     darknet_video.py	      obj		     video_yolov3.sh
# build.sh      data		      obj.data		     yolov3.weights
# cfg	      image_yolov2.sh	      predictions.jpg
# cmake	      image_yolov3.sh	      README.md

# %%
! cat /content/darknet/darknet/obj.data
# Out:
# classes=1
# train = /content/darknet/darknet/train.txt
# test = /content/gdrive/My\ Drive/darknet/test.txt
# names = /content/gdrive/My\ Drive/darknet/obj.names
# backup = /content/gdrive/My\ Drive/darknet/backup
