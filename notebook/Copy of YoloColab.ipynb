# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !ls -lt
# Out:
# total 4
# drwxr-xr-x 1 root root 4096 Jul 10 16:29 sample_data

# %%
# !ls -la "/content/gdrive/My Drive/"
#!ln -s /content/gdrive/My\ Drive/ /mydrive

#! ls -lt "/content/gdrive/My Drive/darknet/cuDNN"
#! mv "/content/gdrive/My Drive/darknet/cuDNN/cudnn-10.0-linux-x64-v7.5.0.56 (1).tgz" "/content/gdrive/My Drive/darknet/cuDNN/cudnn-10.0-linux-x64-v7.5.0.56.tgz"
#! ls -lt "/content/gdrive/My Drive/darknet/cuDNN"
# Out:
# total 0

# %%
% cd /content
# !pwd
# !mkdir darknet darknet/backup darknet/bin darknet/cfg darknet/cuDNN darknet/img darknet/weights
# !ls /content/darknet
# Out:
# /content
# /content
# mkdir: cannot create directory ‘darknet’: File exists
# mkdir: cannot create directory ‘darknet/backup’: File exists
# mkdir: cannot create directory ‘darknet/bin’: File exists
# mkdir: cannot create directory ‘darknet/cfg’: File exists
# mkdir: cannot create directory ‘darknet/cuDNN’: File exists
# mkdir: cannot create directory ‘darknet/img’: File exists
# mkdir: cannot create directory ‘darknet/weights’: File exists
# backup	bin  cfg  cuDNN  img  weights

# %%
# !ls -lt /content
! ls -lt 
#!cp /mydrive/darknet/cuDNN/cudnn-10.0-linux-x64-v7.5.0.56.tgz /content/darknet/cuDNN/
#!ls -lt "/content/darknet/cuDNN"
# Out:
# total 12
# drwxr-xr-x 8 root root 4096 Jul 29 07:25 darknet
# drwx------ 4 root root 4096 Jul 29 06:53 gdrive
# drwxr-xr-x 1 root root 4096 Jul 10 16:29 sample_data
# cp: cannot stat '/mydrive/darknet/cuDNN/cudnn-10.0-linux-x64-v7.5.0.56.tgz': No such file or directory
# total 0

# %%
# !sudo apt-get install tree
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tree is already the newest version (1.7.0-5).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.

# %%
# !tree /content/gdrive/My\ Drive/darknet/
# Out:
# /content/gdrive/My Drive/darknet/
# ├── bin
# │   └── darknet
# ├── cuDNN
# │   └── cudnn-10.0-linux-x64-v7.5.0.56.tgz
# └── img
#     ├── one.JPG
#     ├── test.JPG
#     ├── three.JPG
#     └── two.JPG
#
# 3 directories, 6 files
# bin  cuDNN  img

# %%
! uname -r
# Out:
# 4.19.104+

# %%
 ! cat /proc/version
# Out:
# Linux version 4.19.104+ (chrome-bot@chromeos-ci-legacy-us-central1-b-x32-96-hq3l) (Chromium OS 9.0_pre361749_p20190714-r4 clang version 9.0.0 (/var/cache/chromeos-cache/distfiles/host/egit-src/llvm-project c11de5eada2decd0a495ea02676b6f4838cd54fb) (based on LLVM 9.0.0svn)) #1 SMP Wed Feb 19 05:26:34 PST 2020

# %%
! cat /etc/os-release
# Out:
# NAME="Ubuntu"
# VERSION="18.04.3 LTS (Bionic Beaver)"
# ID=ubuntu
# ID_LIKE=debian
# PRETTY_NAME="Ubuntu 18.04.3 LTS"
# VERSION_ID="18.04"
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# VERSION_CODENAME=bionic
# UBUNTU_CODENAME=bionic

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
# !tar -xzvf /mydrive/cuDNN/cudnn-10.0-linux-x64-v7.5.0.56.tgz -C /usr/local/
# Out:
# cuda/include/cudnn.h
# cuda/NVIDIA_SLA_cuDNN_Support.txt
# cuda/lib64/libcudnn.so
# cuda/lib64/libcudnn.so.7
# cuda/lib64/libcudnn.so.7.5.0
# cuda/lib64/libcudnn_static.a

# %%
# !chmod a+r /usr/local/cuda/include/cudnn.h

# %%
# !cat /usr/local/cuda/include/cudnn.h | grep CUDNN_MAJOR -A 2
# Out:
# #define CUDNN_MAJOR 7
# #define CUDNN_MINOR 5
# #define CUDNN_PATCHLEVEL 0
# --
# #define CUDNN_VERSION (CUDNN_MAJOR * 1000 + CUDNN_MINOR * 100 + CUDNN_PATCHLEVEL)
#
# #include "driver_types.h"

# %%
! pwd
! ls -lt
# Out:
# /content
# total 8
# drwx------ 4 root root 4096 Jul 29 06:21 gdrive
# drwxr-xr-x 1 root root 4096 Jul 10 16:29 sample_data

# %%
##  Cloning and compiling Darkent. ONLY NEEDS TO BE RUN ON THE FIRST EXECUTION!!

# !git clone https://github.com/kriyeng/darknet/
# %cd darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 10068, done.
# remote: Total 10068 (delta 0), reused 0 (delta 0), pack-reused 10068
# Receiving objects: 100% (10068/10068), 10.15 MiB | 14.26 MiB/s, done.
# Resolving deltas: 100% (6735/6735), done.
# /content/darknet/darknet

# %%
# !ls
# Out:
# 3rdparty      CMakeLists.txt	      image_yolov3.sh	     scripts
# appveyor.yml  CMakeSettings.json      include		     src
# build	      DarknetConfig.cmake.in  json_mjpeg_streams.sh  video_v2.sh
# build.ps1     darknet.py	      LICENSE		     video_yolov3.sh
# build.sh      darknet_video.py	      Makefile
# cfg	      data		      net_cam_v3.sh
# cmake	      image_yolov2.sh	      README.md

# %%
#Compile Darknet
# !make
# Out:
# chmod +x *.sh

# %%
! pwd
# Out:
# /content/darknet/darknet

# %%
! ls -lt darknet/darknet
# Out:
# -rwxr-xr-x 1 root root 763000 Jul 28 12:25 darknet/darknet

# %%
! pwd
#Copies the Darknet compiled version to Google drive
# !cp ./darknet /content/gdrive/My\ Drive/darknet/bin/darknet
# Out:
# /content/darknet/darknet

# %%
! ls -Rlt /content/gdrive/My\ Drive/darknet/bin/darknet
# Out:
# -rw------- 1 root root 763000 Jul 28 13:59 '/content/gdrive/My Drive/darknet/bin/darknet'

# %%
# !chmod +x ./darknet

# %%
#download files
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  #plt.rcParams['figure.figsize'] = [10, 5]
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()
  
  
def upload():
  from google.colab import files
  uploaded = files.upload() 
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)
def download(path):
  from google.colab import files
  files.download(path)

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2020-07-28 12:53:24--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M   468KB/s    in 10m 17s
#
# 2020-07-28 13:03:42 (392 KB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
## Copy compiled weights & DARKNET from google drive to VM

# %%
# !ls /mydrive
# !pwd
! ls /content
#! rm -R /content/*
# Out:
# /mydrive
# /content
# gdrive

# %%
% cd /content/gdrive/*
! ls
# Out:
# rmdir: failed to remove '/content/gdrive/My Drive': Directory not empty
# 'My Drive'

# %%
# !cp -R  /mydrive/ /content/

# %%
! ls /content/gdrive
# Out:
# 'My Drive'

# %%
! mkdir log

# %%
% cd /proc/driver/nvidia/gpus
! ls
# Out:
# /proc/driver/nvidia/gpus
# 0000:00:04.0

# %%
# %cd /content/
# !cp /content/gdrive/My\ Drive/darknet/img/test.JPG darknet/img/
# !cp /content/gdrive/My\ Drive/darknet/bin/* darknet
# Out:
# /content
# darknet:
# total 756
# -rw------- 1 root root 763000 Jul 28 12:02 darknet
# drwxr-xr-x 2 root root   4096 Jul 28 12:00 bin
# drwxr-xr-x 2 root root   4096 Jul 28 11:48 img
#
# darknet/bin:
# total 748
# -rw------- 1 root root 763000 Jul 28 12:00 darknet
#
# darknet/img:
# total 196
# -rw------- 1 root root 200518 Jul 28 12:02 test.JPG
# /content/darknet

# %%
! ls -lt
# Out:
# total 4
# drwxr-xr-x 1 root root 4096 Jul 10 16:29 sample_data

# %%
! pwd
# Out:
# /proc/driver/nvidia/gpus

# %%
!

# %%
# Not necessary cell
# Execute darknet using YOLOv3 model with pre-trained weights to detect objects on 'person.jpg'
# !./darknet detect cfg/yolov3.cfg yolov3.weights data/three.JPG -dont-show

# Show the result using the helper imgShow()
imShow('predictions.jpg')
# Out:
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32 0.299 BF
#    1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64 1.595 BF
#    2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32 0.177 BF
#    3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128 1.595 BF
#    6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#    7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#   10 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
#   12 conv    256  3 x 3 / 2   104 x 104 x 128   ->    52 x  52 x 256 1.595 BF
# ...

# %%
! ls -lt "/content/gdrive/My Drive/darknet/obj.data"
! ls -lt "/content/gdrive/My Drive/darknet/yolov3.cfg" 
! ls -lt "/content/gdrive/My Drive/darknet/darknet53.conv.74"
# Out:
# -rw------- 1 root root 217 Jul 28 13:33 '/content/gdrive/My Drive/darknet/obj.data'
# -rw------- 1 root root 9127 Jul 28 13:36 '/content/gdrive/My Drive/darknet/yolov3.cfg'
# -rw------- 1 root root 162482580 Jul 28 14:43 '/content/gdrive/My Drive/darknet/darknet53.conv.74'

# %%
% cd darknet/darknet/
! ls -lt /mydrive/train.txt
! ls -lt  /content/gdrive/My\ Drive/darknet/train.txt
! cp /content/gdrive/My\ Drive/darknet/obj.data .
! cp /content/gdrive/My\ Drive/darknet/train.txt .
! ls
# Out:
# /content/darknet/darknet
# 3rdparty      CMakeLists.txt	      include		     results
# appveyor.yml  CMakeSettings.json      json_mjpeg_streams.sh  scripts
# backup	      darknet		      LICENSE		     src
# bad.list      DarknetConfig.cmake.in  Makefile		     train.txt
# build	      darknet.py	      net_cam_v3.sh	     video_v2.sh
# build.ps1     darknet_video.py	      obj		     video_yolov3.sh
# build.sh      data		      obj.data		     yolov3.weights
# cfg	      image_yolov2.sh	      predictions.jpg
# cmake	      image_yolov3.sh	      README.md

# %%
! pwd
! ls
# Out:
# /content
# sample_data

# %%
#!./darknet detector train "/content/darknet/darknet/obj.data" "/content/gdrive/My Drive/darknet/yolov3.cfg" "/content/gdrive/My Drive/darknet/darknet53.conv.74" -dont_show -mjpeg_port 8090 -map
% cd /content/darknet/darknet
# !./darknet detector train "/content/gdrive/My Drive/darknet/obj.data" "/content/gdrive/My Drive/darknet/yolov3.cfg" "/content/gdrive/My Drive/darknet/darknet53.conv.74" backup/yolo_28jul.weights >> log/yolo_28jul.log -#gpus 0
# Out:
# /content/darknet/darknet
# valid: Using default '/content/darknet/darknet/train.txt'
# layer     filters    size              input                output
#    0 conv     18  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  18 0.168 BF
#    1 conv     18  3 x 3 / 2   416 x 416 x  18   ->   208 x 208 x  18 0.252 BF
#    2 conv     18  1 x 1 / 1   208 x 208 x  18   ->   208 x 208 x  18 0.028 BF
#    3 conv     64  3 x 3 / 1   208 x 208 x  18   ->   208 x 208 x  64 0.897 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128 1.595 BF
#    6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#    7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#   10 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
# ...

# %%
# Out:
# -rw------- 1 root root 1223 Jul 28 13:49 /mydrive/train.txt
# -rw------- 1 root root 1223 Jul 28 13:49 '/content/gdrive/My Drive/darknet/train.txt'

# %%
! pwd
! ls
# Out:
# /content/darknet/darknet
# 3rdparty      CMakeLists.txt	      include		     results
# appveyor.yml  CMakeSettings.json      json_mjpeg_streams.sh  scripts
# backup	      darknet		      LICENSE		     src
# bad.list      DarknetConfig.cmake.in  Makefile		     train.txt
# build	      darknet.py	      net_cam_v3.sh	     video_v2.sh
# build.ps1     darknet_video.py	      obj		     video_yolov3.sh
# build.sh      data		      obj.data		     yolov3.weights
# cfg	      image_yolov2.sh	      predictions.jpg
# cmake	      image_yolov3.sh	      README.md

# %%
! cat /content/darknet/darknet/obj.data
# Out:
# classes=1
# train = /content/darknet/darknet/train.txt
# test = /content/gdrive/My\ Drive/darknet/test.txt
# names = /content/gdrive/My\ Drive/darknet/obj.names
# backup = /content/gdrive/My\ Drive/darknet/backup
